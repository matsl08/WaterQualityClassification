# %%
import kagglehub
#Download latest version of California Housing Price
path = kagglehub.dataset_download("rahmadadeakbar/california-housing-train")
print("Path to dataset files: ",path)
# Out:
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\urllib3\connectionpool.py:464, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     463 try:
# --> 464     self._validate_conn(conn)
#     465 except (SocketTimeout, BaseSSLError) as e:
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\urllib3\connectionpool.py:1093, in HTTPSConnectionPool._validate_conn(self, conn)
#    1092 if conn.is_closed:
# -> 1093     conn.connect()
#    1095 # TODO revise this, see https://github.com/urllib3/urllib3/issues/2791
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\urllib3\connection.py:741, in HTTPSConnection.connect(self)
# ...

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('california-housing-train-dataset/california_housing_train.csv')
df.head
# Out:
# Matplotlib is building the font cache; this may take a moment.
# <bound method NDFrame.head of        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# ...

# %%
sns.relplot(data = df, x = 'total_rooms', y = 'total_bedrooms')

# %%
#prepare independent
import numpy as np
import pandas as pd
df = pd.read_csv('california-housing-train-dataset/california_housing_train.csv')
X = np.array(df['total_rooms']).reshape(-1,1)
print(X)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 4
#       2 import numpy as np
#       3 import pandas as pd
# ----> 4 df = pd.read_csv('california-housing-train-dataset/california_housing_train.csv')
#       5 X = np.array(df['total_rooms']).reshape(-1,1)
#       6 print(X)
#
# ...

# %%
#prepare dependent
y = np.array(df['total_bedrooms']).reshape(-1,1)

# %%
#split train and test data
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20)

# %%
#Train the model
#You can save a model through Pickle
from sklearn.linear_model import LinearRegression

reg = LinearRegression()
model = reg.fit(X_train, y_train)

# %%
#Predict new input data
new_data = np.array([[3000]]) #must be in 2D
predicted_value = model.predict(new_data)
print(predicted_value)
# Out:
# [[603.04648863]]
